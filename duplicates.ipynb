# %%
from difPy import dif

# %%
search = dif(r"C:\Users\logan\Documents\Data Mining\Project\images\carpenter_bees")
# Out:
# Found 375 images with one or more duplicate/similar images in 196.0427 seconds.

# %%
search.result
# Out:
# {'bee (10).jpg': {'location': 'C:\\Users\\logan\\Documents\\Data Mining\\Project\\images\\carpenter_bees/bee (10).jpg',
#   'duplicates': ['C:\\Users\\logan\\Documents\\Data Mining\\Project\\images\\carpenter_bees/bee (1127).jpg']},
#  'bee (100).jpg': {'location': 'C:\\Users\\logan\\Documents\\Data Mining\\Project\\images\\carpenter_bees/bee (100).jpg',
#   'duplicates': ['C:\\Users\\logan\\Documents\\Data Mining\\Project\\images\\carpenter_bees/bee (23).jpg']},
#  'bee (1000).jpg': {'location': 'C:\\Users\\logan\\Documents\\Data Mining\\Project\\images\\carpenter_bees/bee (1000).jpg',
#   'duplicates': ['C:\\Users\\logan\\Documents\\Data Mining\\Project\\images\\carpenter_bees/bee (165).jpg',
#    'C:\\Users\\logan\\Documents\\Data Mining\\Project\\images\\carpenter_bees/bee (576).jpg',
#    'C:\\Users\\logan\\Documents\\Data Mining\\Project\\images\\carpenter_bees/bee (826).jpg',
#    'C:\\Users\\logan\\Documents\\Data Mining\\Project\\images\\carpenter_bees/bee (865).jpg',
# ...
